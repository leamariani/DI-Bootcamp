# %% [markdown]
# Exercise 2 : Statistical Analysis
# Instructions
# In this exercise, you’ll calculate statistical measures for a dataset:
#
# Mean: The average value of a dataset.
# Median: The middle value in a dataset when it is arranged in ascending or descending order.
# Standard Deviation: A measure of the amount of variation or dispersion in a set of values.
# Using NumPy, generate an array of 50 random numbers and compute:
#
# The mean and median.
# The standard deviation.

# %%
import numpy as np

# %%
# Generate an array of 50 random numbers (e.g., from a normal distribution)
data = np.random.randn(50)

# %%
# Compute the mean
mean_value = np.mean(data)

# %%
# Compute the median
median_value = np.median(data)

# %%
# Compute the standard deviation
std_deviation = np.std(data)

# %%
# Print the results
print("Generated Data:", data)
print("Mean:", mean_value)
print("Median:", median_value)
print("Standard Deviation:", std_deviation)
# Out:
# Generated Data: [ 0.54467242  0.61508392  0.26294031 -1.21159436 -1.52602026 -1.72746377
#   0.46724149 -0.03765293 -0.1550458  -0.0028882   0.4794578  -0.43045468
#  -0.46419568 -0.03912671  1.22716549  1.45533343  2.53580775 -0.27637907
#  -0.45212345 -0.57831152  0.08791638  0.17803195  0.64158873 -0.49601859
#   1.40241347 -1.1609315  -0.46662873 -2.04693144  1.2064091  -1.04712907
#  -0.8960489   1.86737456  0.09221504 -0.5180155  -0.63210001  0.03789275
#  -1.3823182   1.33461391 -0.26268054  0.5951823   1.32605348  0.24492076
#  -0.54688382  1.06208949  1.17956878  0.69536396 -0.84966768  0.3558566
#   1.5942835   0.59676979]
# Mean: 0.09759273552352811
# Median: 0.06290456589046063
# Standard Deviation: 0.9748367579130225

# %%
import matplotlib.pyplot as plt

# %%
# Plot histogram
plt.hist(data, bins=10, edgecolor='black', alpha=0.7)
plt.axvline(mean_value, color='red', linestyle='dashed', linewidth=1.5, label=f'Mean: {mean_value:.2f}')
plt.axvline(median_value, color='green', linestyle='dotted', linewidth=1.5, label=f'Median: {median_value:.2f}')
plt.title('Histogram of Random Data')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Boxplot
plt.boxplot(data, vert=False)
plt.title('Boxplot of Random Data')
plt.xlabel('Value')
plt.grid(True)
plt.show()

# %%
# Line chart
plt.plot(data, marker='o', linestyle='-')
plt.title('Line Chart of Random Data')
plt.xlabel('Index')
plt.ylabel('Value')
plt.axhline(np.mean(data), color='red', linestyle='dashed', label='Mean')
plt.axhline(np.median(data), color='green', linestyle='dotted', label='Median')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# Exercise 3 : Date Manipulation
# Instructions
# Create a NumPy array of dates for the month of January 2023. Convert these dates to another format (e.g., YYYY/MM/DD).

# %%
# Create array of dates from Jan 1 to Jan 31, 2023
dates = np.arange('2023-01-01', '2023-02-01', dtype='datetime64[D]')

# %%
# Convert dates to custom string format: YYYY/MM/DD
formatted_dates = np.array([str(date).replace('-', '/') for date in dates])

# %%
# Convert dates to custom string format: YYYY/MM/DD
formatted_dates = np.array([str(date).replace('-', '/') for date in dates])

# %%
print("Original Dates (datetime64):")
print(dates)

print("\nFormatted Dates (YYYY/MM/DD):")
print(formatted_dates)
# Out:
# Original Dates (datetime64):
# ['2023-01-01' '2023-01-02' '2023-01-03' '2023-01-04' '2023-01-05'
#  '2023-01-06' '2023-01-07' '2023-01-08' '2023-01-09' '2023-01-10'
#  '2023-01-11' '2023-01-12' '2023-01-13' '2023-01-14' '2023-01-15'
#  '2023-01-16' '2023-01-17' '2023-01-18' '2023-01-19' '2023-01-20'
#  '2023-01-21' '2023-01-22' '2023-01-23' '2023-01-24' '2023-01-25'
#  '2023-01-26' '2023-01-27' '2023-01-28' '2023-01-29' '2023-01-30'
#  '2023-01-31']
#
# Formatted Dates (YYYY/MM/DD):
# ['2023/01/01' '2023/01/02' '2023/01/03' '2023/01/04' '2023/01/05'
#  '2023/01/06' '2023/01/07' '2023/01/08' '2023/01/09' '2023/01/10'
#  '2023/01/11' '2023/01/12' '2023/01/13' '2023/01/14' '2023/01/15'
#  '2023/01/16' '2023/01/17' '2023/01/18' '2023/01/19' '2023/01/20'
#  '2023/01/21' '2023/01/22' '2023/01/23' '2023/01/24' '2023/01/25'
#  '2023/01/26' '2023/01/27' '2023/01/28' '2023/01/29' '2023/01/30'
#  '2023/01/31']

# %%
# Plot
plt.figure(figsize=(12, 4))
plt.plot(formatted_dates, marker='o', linestyle='-')

# %% [markdown]
# Exercise 4 : Data Manipulation with NumPy and Pandas
# Instructions
# Create a DataFrame with random numbers and perform:
#
# Conditional selection of data.
# Aggregation functions like sum and average.

# %%
# Create random DataFrame
np.random.seed(0)
data = np.random.randint(1, 100, size=(5, 4))
df = pd.DataFrame(data, columns=['A', 'B', 'C', 'D'])

# %%
print("Original DataFrame:")
print(df)
# Out:
# Original DataFrame:
#     A   B   C   D
# 0  45  48  65  68
# 1  68  10  84  22
# 2  37  88  71  89
# 3  89  13  59  66
# 4  40  88  47  89

# %%
condition = df[df['A'] > 50]
print("\nRows where column A > 50:")
print(condition)
# Out:
# Rows where column A > 50:
#     A   B   C   D
# 1  68  10  84  22
# 3  89  13  59  66

# %%
sum_values = df.sum()
print("\nSum of each column:")
print(sum_values)
# Out:
# Sum of each column:
# A    279
# B    247
# C    326
# D    334
# dtype: int64

# %%
mean_values = df.mean()
print("\nAverage (mean) of each column:")
print(mean_values)
# Out:
# Average (mean) of each column:
# A    55.8
# B    49.4
# C    65.2
# D    66.8
# dtype: float64

# %%
df.plot(kind='bar', figsize=(10, 5))
plt.title('Original Random DataFrame')
plt.xlabel('Row Index')
plt.ylabel('Value')
plt.show()

# %%
sum_values.plot(kind='bar', color='skyblue', figsize=(6, 4))
plt.title('Sum of Each Column')
plt.ylabel('Sum')
plt.tight_layout()
plt.show()

# %%
mean_values.plot(kind='bar', color='salmon', figsize=(6, 4))
plt.title('Mean of Each Column')
plt.ylabel('Mean')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Exercise 5 : Image Representation
# Instructions
# Explain how images are represented in NumPy arrays and demonstrate with a simple example (e.g., creating a 5x5 grayscale image).

# %%
image = np.array([
    [  0,  50, 100, 150, 200],
    [ 10,  60, 110, 160, 210],
    [ 20,  70, 120, 170, 220],
    [ 30,  80, 130, 180, 230],
    [ 40,  90, 140, 190, 240]
], dtype=np.uint8)

# Display the image using matplotlib
plt.imshow(image, cmap='gray', vmin=0, vmax=255)
plt.title('5x5 Grayscale Image')
plt.colorbar(label='Pixel Intensity')
plt.axis('off')
plt.show()

# %% [markdown]
# Exercise 9 : Data Conversion
# Instructions
# Demonstrate how to convert a NumPy array to a Pandas DataFrame and vice versa.

# %%
# Create a NumPy array
array = np.array([[1, 2, 3], [4, 5, 6]])

# %%
# Convert to DataFrame
df = pd.DataFrame(array, columns=['A', 'B', 'C'])

# %%
print("NumPy Array:")
print(array)
# Out:
# NumPy Array:
# [[1 2 3]
#  [4 5 6]]

# %%
print("Converted to Pandas DataFrame:")
print(df)
# Out:
# Converted to Pandas DataFrame:
#    A  B  C
# 0  1  2  3
# 1  4  5  6

# %%
# Convert DataFrame back to NumPy array
converted_array = df.to_numpy()

# %%
print("\nConverted back to NumPy Array:")
print(converted_array)
# Out:
# Converted back to NumPy Array:
# [[1 2 3]
#  [4 5 6]]
